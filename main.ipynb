# %% [markdown]
# # API Scavenger Game
#
# # Challenge 1: Fork Languages

# %% [markdown]
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is `ironhack-datalabs/madrid-oct-2018`, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the `language` attribute of each fork. Use an array to store the `language` attributes of each fork.
#     * *Hint: Each language should appear only once in your array.*
#
# 3. Print the language array. It should be something like:
#
#   ```["Python", "Jupyter Notebook", "HTML"]```

# %%
# 1. Obtain the full list of forks created from the main lab via Github API

#import libraries
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

#get API url
url = 'https://api.github.com/users/ta-datapt-bcn/repos'

header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}

response = requests.get(url, headers=header)
results = response.json()
results
# Out:
# [{'id': 186247516,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODYyNDc1MTY=',
#   'name': 'data-prework-labs',
#   'full_name': 'ta-datapt-bcn/data-prework-labs',
#   'private': False,
#   'owner': {'login': 'ta-datapt-bcn',
#    'id': 50545821,
#    'node_id': 'MDQ6VXNlcjUwNTQ1ODIx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/50545821?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ta-datapt-bcn',
#    'html_url': 'https://github.com/ta-datapt-bcn',
#    'followers_url': 'https://api.github.com/users/ta-datapt-bcn/followers',
#    'following_url': 'https://api.github.com/users/ta-datapt-bcn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ta-datapt-bcn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ta-datapt-bcn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ta-datapt-bcn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ta-datapt-bcn/orgs',
# ...

# %%
len(results)
# Out:
# 30

# %%
#2. Loop the JSON response to find out the `language` attribute of each fork. 
#Use an array to store the `language` attributes of each fork.

#iterate for all the elements
languages = [results[l]['language'] for l in range(len(results))]

#exclude duplicated
languages = list(set(languages))

# %%
#3. Print the results

languages
# Out:
# ['HTML', 'Jupyter Notebook', None]

# %% [markdown]
# ## Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
# 1. Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# 2. Count how many commit objects are contained in the array.

# %%
# 1. Obtain all the commits made in the past week via API

repos = [results[repo]['full_name'] for repo in range(len(results))]

#first element
#url_0 = 'https://api.github.com/repos/'+repos[0]+'/commits'
#response = requests.get(url_0, headers=header)
#result = response.json()

#for loop to extract the commits
result = []
for i in range(len(repos)):
    url = 'https://api.github.com/repos/'+repos[i]+'/commits'
    response = requests.get(url_0, headers=header)
    json_response = response.json()
    result.append(json_response)

# %%
# extract all dates from commit repos

dates = [[repos[i], j['commit']['author']['date']] for i in range(len(repos)) for j in result[i]]

dates
# Out:
# [['ta-datapt-bcn/data-prework-labs', '2019-01-31T19:47:08Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-31T19:43:43Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-31T19:42:50Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-31T19:13:42Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-31T19:10:01Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-30T12:54:37Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-30T12:35:57Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-30T11:51:20Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-30T11:35:07Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-24T15:36:05Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-24T12:37:38Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-14T08:41:07Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-11T14:19:21Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-10T13:10:14Z'],
#  ['ta-datapt-bcn/data-prework-labs', '2019-01-10T13:00:33Z'],
# ...

# %%
# select dates from the (2019-01-31 to 2019-01-24)
dates_check = ['2019-01-31', '2019-01-30', '2019-01-29', '2019-01-28', '2019-01-27', '2019-01-26', '2019-01-25', '2019-01-24']

#it gives me accumulated not unique... 
result = {}
counts=0
for i, j in dates:
    date = j[0:10]
    if date in dates_check:
        counts += 1

result
# Out:
# {}

# %%
# 2. Count how many commit objects are contained in the array.

len(dates)
# Out:
# 510

# %%
## PUT Challenge

with open('test.txt', 'r') as f:
    content = f.read()
    headers = header
resp = requests.put(data=content.encode('utf-8'), headers=headers)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-134-b5026dc47c20> in <module>
#       1 ## PUT Challenge
#       2
# ----> 3 with open('test.txt', 'r') as f:
#       4     content = f.read()
#       5     headers = header
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'
